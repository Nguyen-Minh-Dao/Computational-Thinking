# %% [markdown]
# ### 1

# %%
a,b = map(int, input().split())
print(a*b, (a+b)*2)

# %% [markdown]
# ### 2

# %%
import math
r = int(input())
print(math.pi *r*r)

# %% [markdown]
# ### 3

# %%
a,b,c = map(int, input().split())
if a+b > c and a+c > b and b+c > a:
    if a == b == c:
        print("Tam giác đều")
    elif a == b or a == c or b == c:
        print("Tam giác cân")
    else:
        print("Tam giác thường")
else:
    print("Không là 3 cạnh của 1 tam giác")

# %% [markdown]
# ### 4

# %%
a,b = map(int, input().split())
if a == 0:
    if b == 0:
        print("Vô số nghiệm")
    else:
        print("Vô nghiệm")
else:
    print(-b/a)

# %% [markdown]
# ### 5

# %%
a,b,c = map(int, input().split())
if b**2 - 4*a*c > 0:
    print(-b+math.sqrt(b**2 - 4*a*c)/2*a, -b-math.sqrt(b**2 - 4*a*c)/2*a)
elif b**2 - 4*a*c == 0:
    print(-b/2*a)
else:
    print("Vô nghiệm")

# %% [markdown]
# ### 6

# %%
x = list(map(int, input().split()))
print(max(x))

# %% [markdown]
# ### 7

# %%
x = list(map(int, input().split()))
print(min(x))

# %% [markdown]
# ### 8

# %%
a,b,c,d,m,n = map(int, input().split())
print((m*d-n*b)/(a*d-b*c), (n-c*(m*d-n*b)/(a*d-b*c))/d)

# %% [markdown]
# ### 9

# %%
n = int(input())
print(n//3600, "giờ", (n%3600)//60, "phút", (n%3600)%60, "giây")
# Out:
# 0 giờ 1 phút 0 giây

# %% [markdown]
# ### 10

# %%
r = int(input())
x,y = map(int, input().split())
print((x-r)**2 + (y-r)**2 == r**2)

# %% [markdown]
# ### 11

# %%
x,y = map(float, input().split())
print(x**y)
# Out:
# 14.33666729017728
