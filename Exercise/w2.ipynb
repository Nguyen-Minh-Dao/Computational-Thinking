# %% [markdown]
# ### W2A1

# %%
print("Hello World!")

# %% [markdown]
# ### W2A2

# %%
print(f"Hello {input()}")
# Out:
# Hello mychael

# %% [markdown]
# ### W2A3

# %%
a,b = map(int, input().split())
print(a + b, a - b, a * b, a//b, a % b, f"{a/b:.2f}")
# Out:
# 11 3 28 1 3 1.75

# %% [markdown]
# ### W2A4

# %%
a1, b1, c1, a2, b2, a3 = map(int, input().split())
print(f"{(a1+b1+c1+(a2+b2)*2+a3*3)/10:.1f}")
# Out:
# 10.0

# %% [markdown]
# ### W2A5

# %%
a, b = map(int, input().split())
print(a**b)

# %% [markdown]
# ### W2A6

# %%
s = input()
print(ord(s), s.upper())

# %% [markdown]
# ### W2A7

# %%
print(((13**2)*3)+5, 13**2*3+5)
# Out:
# 512 512

# %% [markdown]
# ### W2A8

# %%
print(f"{9/5*float(input())+32:.2f}")
# Out:
# 41.00

# %% [markdown]
# ### W2A9

# %%
print(f"{float(input())*1.4:.2f}")

# %% [markdown]
# ### W2A10

# %%
a,b,c = map(str, input().split())
print(f"Hi {c}, {b} and {a}.")
# Out:
# Hi Helen, Alice and Bob.

# %% [markdown]
# ### W2A11

# %%
h, m = map(int, input().split())
print(h*3600+m*60)

# %% [markdown]
# ### W2A12

# %%
print(6*int(input())**2)
# Out:
# 6

# %% [markdown]
# ### W2A13

# %%
a,b = map(int, input().split())
print((a*b)%10)

# %% [markdown]
# ### W2A14

# %%
a,b = map(int, input().split())
a,b = b,a
print(a, b)

# %% [markdown]
# ### W2A15

# %%
print(6*int(input())*(int(input())-1)+1)

# %% [markdown]
# ### W2A16

# %%
print("Spring\nSummer\nAutumn\nWinter")

# %% [markdown]
# ### W2A17

# %%
print("*")
print("***")
print("*****")

# %% [markdown]
# ### W2A18

# %%
print("""### # #   ### ###
 #  #  #   #   #
 #  #   #  #   #
 #  #   #  #   #
 #  ##    #   #""")

# %% [markdown]
# ### W2A19

# %%
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")

# %% [markdown]
# ### W2A20

# %%
print("""January
February
March
April
May
June
July
August
September
October
November
December""")

# %% [markdown]
# ### W2A21

# %%
print("Hello, world\n" * 10)
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
